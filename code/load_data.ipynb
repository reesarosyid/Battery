# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Hasil_Scaraping_Dataset_Li_Baterai.csv')
df.head()
# Out:
#   id_charge id_discharge working_ion  average_voltage  max_delta_volume_per  \
# 0     mp-95      mp-7507          Li         0.013164             27.945411
# 1     mp-95   mp-1187126          Li        -0.249733             16.698268
# 2     mp-95    mp-972285          Li        -0.340509             18.634069
# 3     mp-96      mp-1125          Li         1.919919             21.099782
# 4     mp-96   mp-1180520          Li         1.443582             10.690249
#
#    charge_space_group charge_crystal_system  charge_bandgap_minimum  \
# 0                 229                 Cubic                   0.000
# 1                 229                 Cubic                   0.000
# 2                 229                 Cubic                   0.000
# 3                  13            Monoclinic                   2.748
# 4                  13            Monoclinic                   2.748
#
#    charge_specific_volume_mode  charge_specific_volume_range  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52402 entries, 0 to 52401
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id_charge                            52402 non-null  object
#  1   id_discharge                         52402 non-null  object
#  2   working_ion                          52402 non-null  object
#  3   average_voltage                      52402 non-null  float64
#  4   max_delta_volume_per                 52402 non-null  float64
#  5   charge_space_group                   52402 non-null  int64
#  6   charge_crystal_system                52402 non-null  object
#  7   charge_bandgap_minimum               52402 non-null  float64
#  8   charge_specific_volume_mode          52402 non-null  float64
#  9   charge_specific_volume_range         52402 non-null  float64
#  10  charge_specific_volume_deviation     52402 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                        count       mean         std  \
# average_voltage                      52402.0   2.885355    2.371259
# max_delta_volume_per                 52402.0  38.212497  177.153581
# charge_space_group                   52402.0  64.760467   73.788292
# charge_bandgap_minimum               52402.0   0.687142    0.941643
# charge_specific_volume_mode          52402.0  14.471461   18.550728
# charge_specific_volume_range         52402.0   0.000000    0.000000
# charge_specific_volume_deviation     52402.0   0.000000    0.000000
# charge_X_mean                        52402.0   2.172598    0.376920
# charge_X_min                         52402.0   1.285943    0.402806
# charge_X_max                         52402.0   3.280048    0.633512
# charge_X_range                       52402.0   1.994105    0.766065
# charge_X_deviation                   52402.0   0.831636    0.304918
# charge_covalent_radius_mean          52402.0   1.122565    0.175025
# ...
